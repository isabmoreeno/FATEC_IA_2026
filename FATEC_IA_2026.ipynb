# %% [markdown]
# <a href="https://colab.research.google.com/github/isabmoreeno/FATEC_IA_2026/blob/main/FATEC_IA_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input ('Informe o seu nome: ')
# Out:
# Informe o seu nome: Isa

# %%
print(nome)
# Out:
# Isa

# %%
valor1 = 5; valor2 = 2
soma = valor1 + valor2

print('O resultado final é: ', soma)
print('O resultado final é: %d' % soma)
print('O resultado final é: {}' .format(soma))
# f ou F - formatted string literals
print(f'O resultado final é: {soma}')
# Out:
# O resultado final é:  7
# O resultado final é: 7
# O resultado final é: 7
# O resultado final é: 7

# %%
a = 10; b = 20; c = 30
d = a + b
print(d)

e = c /a
print(e)

f = a - b
print(f)

g = b * c
print(g)
h = 3
i = b / h
print(i)

j = float(a)
print(a, j)

a = 13
resto = a % 2
print(f'O resto da divisão é: {resto}')
print (10/3)

a+=1
print(a)
# Out:
# 30
# 3.0
# -10
# 600
# 6.666666666666667
# 10 10.0
# O resto da divisão é: 1
# 3.3333333333333335
# 14

# %%
# Funções Matemáticas
import math

#Exponenciação
a = 3 ** 2
print(a)

#Radiciação
b = math.sqrt(a)
print(b)

print(math.pi)

n = 0
print(math.cos(n))
print(math.sin(n))
# Out:
# 9
# 3.0
# 3.141592653589793
# 1.0
# 0.0

# %%
# Entrada de Dados com vários tipos

nome = input('Digite o seu nome: ')
idade = input('Digite sua idade: ')
print(f'Nome: {nome}')
print(f'Idade: {idade}')

num1 = int(input('Digite num1: '))
num2 = int(input('Digite num2: '))
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)

num3 = float(input('Digite num3: '))
print(num3)
# Out:
# Digite o seu nome: Isa
# Digite sua idade: 18
# Nome: Isa
# Idade: 18
# Digite num1: 19
# Digite num2: 20
# 39
# -1
# 380
# 0.95
# Digite num3: 20
# 20.0
